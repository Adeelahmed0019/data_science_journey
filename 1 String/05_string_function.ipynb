# %% [markdown]
# # **String Functions**
#
# ### Function: is the `predefined` set of code, that is used by the programmer to save the time.
# ### `Function call`is called by **its name** and **round brakets**
# ### `Note`
# #### String function perform task, but its an `independent entity` whereas `string method` is a collection/ group of functions called `object`

# %% [markdown]
# ### **len()**
# ##### Used to count the `length[also spaces(s)]` of the `string`

# %% [markdown]
# # **`String formating`**
# ### There are mainly `three` string formating
# #### `1` simple
# #### `2` **f** formating
# #### `3` **r** formating
# #### `4` **format()** formating

# %% [markdown]
# ### `1` simple

# %%
name = 'Adeel'
number = 10
print("This is the simple 'string formating'")
print("my name is", name, "and my number is", number)
# Out:
# This is the simple 'string formating'
# my name is Adeel and my number is 10

# %% [markdown]
# ### `2` **f** formating
# #### Use `f` before quotation and use curly barckets to pass the variable name

# %%
name = 'Adeel'
number = 10
print("This is the  'f_string formating'")
print(f"my name is {name} and my number is {number}")
# Out:
# This is the  'f_string formating'
# my name is Adeel and my number is 10

# %% [markdown]
# ### `3` **r** formating
# #### Use `r` before quotation, it will print anything written inside the quatation even `escape-sequences`

# %%
print(r'This is the\n "r" string formating')
# Out:
# This is the\n "r" string formating

# %% [markdown]
# ### `4` **format()** formating
# #### It is `function` use `after` quatations end and, it take multiple values

# %%
name = 'Adeel'
number = 10
print("This is the simple 'string formating'")
print("my name is {} and my number is {}".format(name, number))
# Out:
# This is the simple 'string formating'
# my name is Adeel and my number is 10

# %%
srt = "string function"
print(len(srt)) 
# print(str[0:len(str)])
# Out:
# 15

# %% [markdown]
# ### **capitalize()**
# ##### It returns the `exact` copy of the `string` with only the `first` letter in `upper-case`

# %%
C_str = "important"
print("Orginal string is: ", C_str)
print("After 'capitalize function string is :'",C_str.capitalize())
# Out:
# Orginal string is:  important
# After 'capitalize function string is :' Important

# %% [markdown]
# ### **find()**
# ##### It is used to `search` the first `occurrence` of the `sub-string` in the given `string`
# ##### It retuns the `index` at which the `substring` **Start**

# %%
f_str = "find function"
print(f_str)
print(f_str.find("f")) # It will return the Index
print(f_str.find("io"))
# Out:
# find function
# 0
# 10

# %% [markdown]
# ### **isalnum()** [is alpha-numeric]
# ##### It will return `True` if the string contains only `letters` or `digits`
# ##### It returns `False` if any `special` character occurs even ``

# %%
srt1 = "abc123"
str2 = "abc 123"
print(srt1.isalnum()) # it return `True` bc there is no space in srt1
print(str2.isalnum()) # it return `False` bc there is space in str2
# Out:
# True
# False

# %% [markdown]
# ### **isalpha()**
# ##### It retuns `True` if all the character in the `string` are `alphabets` otherwise return `False`

# %%
srt_isalpha = "abc"
srt_isalpha_2 = "asd@" 
print(srt_isalpha.isalpha()) # it return `True` bc there is only alphabet in srt_isalpha
print(srt_isalpha_2.isalpha()) # it return `False` bc there is `@` in srt_isalpha_2
# Out:
# True
# False

# %% [markdown]
# ### **isdigit()**
# ##### `inverse` of the `isalpha()`

# %%
srt_digit = "123"
srt_digit_2 = "123a"
print(srt_digit.isdigit()) # it return `True` bc there is only digit in srt_digit
print(srt_digit_2.isdigit()) # it return `False` bc there is `a` in srt_digit_2
# Out:
# True
# False

# %% [markdown]
# ### **lower()**
# #### It return exact the copy of the `string` with all the letter in `lower-case`

# %%
srt_lower = "PYTHON"
print("orignal string is ==>", srt_lower,"after 'lower() function': ",srt_lower.lower()) # it convert string into lower-case
# Out:
# orignal string is ==> PYTHON after 'lower() function':  python
# Python

# %% [markdown]
# ### **islower()**
# #### It returns `True` if all the `character` in the string are in `lower-case` otherwise it returns `false`

# %%
srt_islower = "data science"
srt_islower2 ="Data Science"
print("orignal string is ==>",srt_islower,":: output is: ", srt_islower.islower()) # it return `True` bc there is only lower-case in srt_islower
print("orignal string is ==>", srt_islower,":: output is ", srt_islower2.islower()) # it return `False` bc there is upper-case in srt_islower2
# Out:
# orignal string is ==> data science :: output is:  True
# orignal string is ==> data science :: output is  False

# %% [markdown]
# ### **upper()**
# #####
# #### It return exact the copy of the `string` with all the letter in `upper-case`

# %%
srt_upper = "data science"
print("orignal string is ==>",srt_upper,":: output is: ", srt_upper.upper())
# Out:
# orignal string is ==> data science :: output is:  DATA SCIENCE

# %% [markdown]
# ### **isupper()**
# ##### It returns `True` if all the `character` in the string are in `upper-case` otherwise it returns `false`

# %%
srt_isupper = "programming"
srt_isupper2 = "PROGRAMMING"
print("orignal string is ==>", srt_isupper,":: output is: ", srt_isupper.isupper()) # it return `False` bc there is only lower-case in srt_isupper
print("orignal string is ==>", srt_isupper2,":: output is: ", srt_isupper2.isupper()) # it return `True` bc there is only upper-case in srt_isupper2
# Out:
# orignal string is ==> programming :: output is:  False
# orignal string is ==> PROGRAMMING :: output is:  True

# %% [markdown]
# ### **lstrip()**
# ##### Returns the `String` after `removing` the `space(s)` on the `left` of the string
# ##### And also remove the character from left side that you passed in *Istrip()* function
# ####

# %%
# Remove space from left side of the string

srt_lstrip = "  data science   "

# This is orignal string 
print("orignal string 'str_1strip is ' ==>",srt_lstrip)

# The length of string is 17 
print("\nThe length of srt1 is : ",len(srt_lstrip))

# it remove space from left side of the string
print("After applying 'lstrip function' on ste_1strip: ", srt_lstrip.lstrip())

# The length of string is 15 because there are two space in left side of the string 
print("The length of string after applying 'lstrip function' on str_1strip is : ",len(srt_lstrip.lstrip()))

print('*'*100)

#########################################################################################################################

# Remove character 'd' from left side of the string


srt_lstrip2 = "dddata science"

# This is orignal string
print("orignal string 'str_2strip is ' ==>", srt_lstrip2)

# The length of string is 13
print("\nThe length of srt2 is : ",len(srt_lstrip2))

# it remove `d` from left side of the string
print("After applying 'lstrip function' on str_2strip: ", srt_lstrip2.lstrip("d"))

# The length of string is 12 because there are one `d` in left side of the string
print("The length of string after applying 'lstrip function' on str_2strip is : ",len(srt_lstrip2.lstrip("d")))
# Out:
# orignal string 'str_1strip is ' ==>   data science
#
# The length of srt1 is :  17
# After applying 'lstrip function' on ste_1strip:  data science
# The length of string after applying 'lstrip function' on str_1strip is :  15
# ****************************************************************************************************
# orignal string 'str_2strip is ' ==> dddata science
#
# The length of srt2 is :  14
# After applying 'lstrip function' on str_2strip:  ata science
# The length of string after applying 'lstrip function' on str_2strip is :  11

# %% [markdown]
# ### **rstrip()**
# ##### Returns the `String` after `removing` the `space(s)` on the `right` of the string
# ##### And also remove the character from right side that you passed in *rstrip()* function
# ####

# %%
# Remove space from left side of the string

srt_rstrip = "data science   "

# This is original string 
print("original string 'str_1strip is ' ==>",srt_rstrip)

# The length of string is 17 
print("\nThe length of srt1 is : ",len(srt_rstrip))

# it remove space from right side of the string
print("After applying 'rstrip function' on srt_1strip: ", srt_rstrip.rstrip())

# The length of string is 15 because there are two space in right side of the string 
print("The length of string after applying 'rstrip function' on str_1strip is : ",len(srt_rstrip.rstrip()))

print('*'*100)

#########################################################################################################################

# Remove character 'd' from left side of the string


srt_rstrip2 = "data sciencewww"

# This is original string
print("original string 'str_2strip is ' ==>", srt_rstrip2)

# The length of string is 13
print("\nThe length of srt2 is : ",len(srt_rstrip2))

# it remove `w` from right side of the string
print("After applying 'rstrip function' on str_2strip: ", srt_rstrip2.rstrip("w"))

# The length of string is 12 because there are one `w` in right side of the string
print("The length of string after applying 'rstrip function' on str_2strip is : ",len(srt_rstrip2.rstrip("w")))
# Out:
# original string 'str_1strip is ' ==> data science
#
# The length of srt1 is :  15
# After applying 'rstrip function' on srt_1strip:  data science
# The length of string after applying 'rstrip function' on str_1strip is :  12
# ****************************************************************************************************
# original string 'str_2strip is ' ==> data sciencewww
#
# The length of srt2 is :  15
# After applying 'rstrip function' on str_2strip:  data science
# The length of string after applying 'rstrip function' on str_2strip is :  12

# %% [markdown]
# ### **isspace()**
# #### This fuction returns `true` only if a string `only` contains `spaces`
# #### This function returns `false` only when a string is containing any value `except` *spaces*

# %%
isspace_srt = " "
not_isspace_srt = " data science  "

# It return `True` bc there is only space in isspace_srt
print("original string is ==>", isspace_srt, ":: output is: ", isspace_srt.isspace()) 

# It return `False` bc there is not only space in not_isspace_srt
print("original string is ==>", not_isspace_srt, ":: output is: ", not_isspace_srt.isspace())
# Out:
# original string is ==>   :: output is:  True
# original string is ==>  data science   :: output is:  False

# %% [markdown]
# ### **istitle()**
# ##### It checkes the string, and returns `true` if the first letter of each word in a string is  in upper-case

# %%
is_title = "The Green Revolution"
not_title = "the green revolution"
print("output :: ", is_title.istitle())  
print("output :: ", not_title.istitle())
# Out:
# output ::  True
# output ::  False

# %% [markdown]
# ### **replace()**
# ##### It is used to `replace` any value from string, it takes 3 valuse, 1st: 'valus you want to replace', 2nd: 'add new valus' 3dr value for `index` if you want to mention

# %%
str_replace = "Hellow"
print("The original string is :: ", str_replace)
print("replaced stirng is :: ", str_replace.replace('l','i'))
print("replaced stirng is :: ", str_replace.replace('l','i',1)) # it will replace only first occurence of `l` with `i`
# Out:
# The original string is ::  Hellow
# replaced stirng is ::  Heiiow
# replaced stirng is ::  Heilow

# %% [markdown]
# ### **join()**
# ##### Join function `joins` the list items with separator

# %%
simple_str = ["Jan", "Feb", "Mar"]

print("original string is : ", simple_str)
print("The data type of 'simple_str is : ' ",type(simple_str))

separator = ", "
print("The data type of 'separator is : ' ",type(separator))

new = separator.join(simple_str)
print("After 'join' funtion : ", separator.join(simple_str))
print("The data type of 'new' is : ' ",type(new))
# Out:
# original string is :  ['Jan', 'Feb', 'Mar']
# The data type of 'simple_str is : '  <class 'list'>
# The data type of 'separator is : '  <class 'str'>
# After 'join' funtion :  Jan, Feb, Mar
# The data type of 'new' is : '  <class 'str'>

# %% [markdown]
# #### **swapcase()**
# ##### This function `swap` the string lower-case to uper-case and wise-varsa

# %%
swap_str = "ADEEL"
swap_str2 = "adeel"
print("The original string is :: ", swap_str)
print('After applying "swapcase()" function :: ', swap_str.swapcase())
print("The original string is :: ", swap_str2)
print('After applying "swapcase()" function :: ', swap_str2.swapcase())
# Out:
# The original string is ::  ADEEL
# After applying "swapcase()" function ::  adeel
# The original string is ::  adeel
# After applying "swapcase()" function ::  ADEEL

# %% [markdown]
# ### **split()**
# #### `spilt()` funciton spilt the `string` in words but in `list` format
# #### **limit split with mwxsplit**: how many words you want to spilt

# %%
# string
srt_split = "I love python programmning language"

print("The original string is :: ", srt_split)
print("The data type of 'srt_split is : ' ",type(srt_split))

new_1 = srt_split.split()
print("String after applying 'split()' function :: ", new_1)
print("The data type of 'new_1' is : ' ",type(new_1))

new_2 = srt_split.split("-",3)
print("String after applying 'split()' function :: ", new_2)
print("The data type of 'new_2' is : ' ",type(new_2))
# Out:
# The original string is ::  I love python programmning language
# The data type of 'srt_split is : '  <class 'str'>
# String after applying 'split()' function ::  ['I', 'love', 'python', 'programmning', 'language']
# The data type of 'new_1' is : '  <class 'list'>
# String after applying 'split()' function ::  ['I love python programmning language']
# The data type of 'new_2' is : '  <class 'list'>

# %% [markdown]
# ### **partition()**
# #### It gives `output` in three elements
# ##### 1: characters that appears `before` the partition
# ##### 2: `partition` character like: `common`
# ##### 3: character that appears `after` the partition

# %%
partition_str = "The is string partition functions"
print("The original string is :: ", partition_str)
print('Srting after `partition` function', partition_str.partition('ing'))
# Out:
# The original string is ::  The is string partition functions
# Srting after `partition` function ('The is str', 'ing', ' partition functions')

# %% [markdown]
# ### **index()**
# #### it works same as `fine()` but it will return `value error` when the index is out of range
# #### The index function always take value as `string`

# %%
index_str = "The is string index functions"
print("The original string is :: ", index_str)
print('Srting after `index` function', index_str.index('i'))
print(len(index_str))
#print(index_str.index(z))  #NameError: name 'z' is not defin
# Out:
# The original string is ::  The is string index functions
# Srting after `index` function 4
# 29

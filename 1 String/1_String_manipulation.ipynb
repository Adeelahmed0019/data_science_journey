# %% [markdown]
# # String manipulation

# %%
# string manipulation excercise
# string concatination done wih `+` sign
# e.g print("Hellow " + "jenny") # it will print "Hello jenny"
# New lins can be created with a backslash and n

# %%
print("string manipulation excercise")
print("string concatinantion done with '+' sign")
print('e.g print("Hellow "+" "jenny")')
print("New lins can be created with a backslash and n")
# Out:
# string manipulation excercise
# string concatinantion done with '+' sign
# e.g print("Hellow "+" "jenny")
# New lins can be created with a backslash and n

# %% [markdown]
# # `Input function`  in python

# %% [markdown]
# #### By default *input function's* return `string` value, we change *string* into any type easily

# %%
# print this:
# What is your name?
# Hey adeel, how are you
name = input("What is your name? ")
print(f"Hey {name}, how are you?")
print(type(name))

# print("Hey"+" " + input("What is your name? ")+", how are you?")
# Out:
# Hey Adeel, how are you?
# <class 'str'>

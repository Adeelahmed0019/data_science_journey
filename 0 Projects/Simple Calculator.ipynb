# %% [markdown]
# # **`Mini Project  —  Simple Calculator`**

# %%
# --- Simple Calculator --
number_1 = float(input("Enter first number: "))
number_2 = float(input("Enter second number: "))
print("Addition:      ", number_1 + number_2)
print("Subtraction:   ", number_1 - number_2)
print("Multiplication:", number_1 * number_2)
print("Division:      ", number_1 / number_2)
print("Floor Division:", number_1 // number_2)
print("Modulus:       ", number_1 % number_2)
print("Power:         ", number_1 ** number_2)
# Out:
# Addition:       5.0
# Subtraction:    -1.0
# Multiplication: 6.0
# Division:       0.6666666666666666
# Floor Division: 0.0
# Modulus:        2.0
# Power:          8.0

# %%
# --- Simple Calculator --
user_preference = input("Do you want to enter numbers as integers or floats? (int/float): ")
number_1 = input("Enter first number: ")
number_2 = input("Enter second number: ")

if user_preference == "int":
    number_1 = int(number_1)
    number_2 = int(number_2)
    print("Addition:      ", number_1 + number_2)
    print("Subtraction:   ", number_1 - number_2)
    print("Multiplication:", number_1 * number_2)
    print("Floor Division:", number_1 // number_2)
    print("Modulus:       ", number_1 % number_2)
    print("Power:         ", number_1 ** number_2)
elif user_preference == "float":
    number_1 = float(number_1)
    number_2 = float(number_2)
    print("Addition:      ", number_1 + number_2)
    print("Subtraction:   ", number_1 - number_2)
    print("Multiplication:", number_1 * number_2)
    print("Division:      ", number_1 / number_2)
    print("Floor Division:", number_1 // number_2)
    print("Modulus:       ", number_1 % number_2)
    print("Power:         ", number_1 ** number_2)
# Out:
# Addition:       6.3
# Subtraction:    -0.2999999999999998
# Multiplication: 9.899999999999999
# Division:       0.9090909090909092
# Floor Division: 0.0
# Modulus:        3.0
# Power:          37.540507598529544

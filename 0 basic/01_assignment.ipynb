# %% [markdown]
# # First_assignment_on_print_funtion

# %%
print("print - python print function")
print('It is decleared like this:')
print('print("what to print")')
# Out:
# print - python print function
# It is decleared like this:
# print("what to print")
